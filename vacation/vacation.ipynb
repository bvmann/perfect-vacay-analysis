# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import gkey

# %%
gkey
# Out:
# 'AIzaSyBHgZv5iqCzKonQOnWwsbvJmWs87HJAMBo'

# %%
vacay = pd.read_csv('../output_data/cities_clean.csv')

# %%
vacay
# Out:
#       City Name      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    shrewsbury  52.7101   -2.7521    280.15      87.0        75.0
# 1        sangar  63.9242  127.4739    265.12      83.0        47.0
# 2         vaini -21.2000 -175.2000    297.15      83.0        75.0
# 3    bredasdorp -34.5322   20.0403    283.15      93.0        99.0
# 4       chifeng  42.2683  118.9636    283.33      20.0         0.0
# ..          ...      ...       ...       ...       ...         ...
# 574    chimbote  -9.0853  -78.5783    291.86      90.0        76.0
# 575     dahegam  23.1667   72.8167    303.15      30.0        40.0
# 576     issenye  -2.0000   34.3333    289.22      95.0        34.0
# 577      igarka  67.4667   86.5833    273.55      86.0       100.0
# 578  filadelfia  39.9523  -75.1638    295.37      46.0        75.0
#
#      Wind Speed Country          Date
# 0          3.60      GB  1.619569e+09
# 1          3.82      RU  1.619569e+09
# 2          7.72      TO  1.619569e+09
# ...

# %%
vacay.dtypes
# Out:
# City Name      object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity      float64
# Cloudiness    float64
# Wind Speed    float64
# Country        object
# Date          float64
# dtype: object

# %%
gmaps.configure(api_key=gkey)

# %%
#create gmap variables for latitudes and longitudes
coord = vacay[['Lat','Lng']]
#create gmap variables for humidity
humid = vacay["Humidity"]

#check to see what each one looks like; data types and such 
coord

humid
# Out:
# 0      87.0
# 1      83.0
# 2      83.0
# 3      93.0
# 4      20.0
#        ...
# 574    90.0
# 575    30.0
# 576    95.0
# 577    86.0
# 578    46.0
# Name: Humidity, Length: 579, dtype: float64

# %%
humidity = gmaps.figure()

# %%
humid_heat = gmaps.heatmap_layer(coord, weights=humid)

humidity.add_layer(humid_heat)

# %%
humidity
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
humid_heat.max_intensity = 150

# %%
humid_heat.point_radius = 6

# %%
vacay[['Wind Speed', 'Max Temp', 'Cloudiness',
                 'Humidity']] = vacay[['Wind Speed', 'Max Temp', 'Cloudiness',
                 'Humidity']].apply(pd.to_numeric)

# %%
vacay.dtypes
# Out:
# City Name      object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity      float64
# Cloudiness    float64
# Wind Speed    float64
# Country        object
# Date          float64
# dtype: object

# %%
# vacation spot specs : windspeed = 4 , maxtemp <=311 , cloudiness <=11,  humidity <= 35
# note : temperatures recorded in Kelvin

# %%
#applied .loc using preferred specifications

vacay_hotel = vacay.loc[(vacay['Wind Speed']<=4.0)& (vacay['Max Temp']<=311.0) & (vacay['Cloudiness']<=11.0) & (vacay['Humidity']<=35.0)]

# %%
vacay_hotel
# Out:
#     City Name      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 60      kutum  14.2000   24.6667    295.63      15.0        11.0        2.50
# 114    bethel  41.3712  -73.4140    289.15      29.0         1.0        2.06
# 140   sakakah  29.9697   40.2064    291.15      25.0         0.0        1.54
# 242    shache  38.4167   77.2406    287.76      20.0         0.0        0.31
# 419  gallatin  45.6666 -111.2008    288.71      26.0         1.0        1.54
# 467      esna  25.2934   32.5540    295.15      24.0         0.0        1.03
# 501       hit  33.6416   42.8251    296.33      29.0         0.0        2.44
# 512   ushtobe  45.2514   77.9838    287.44      32.0         3.0        1.92
# 536      guna  24.6500   77.3167    299.62      18.0         0.0        2.45
# 547   yangcun  39.3639  117.0603    291.15      20.0         0.0        4.00
# 555   ratholo -22.7245   27.5720    291.04      22.0         0.0        0.49
# ...

# %%
#small dataset for api usage 
len(vacay_hotel)
# Out:
# 12

# %%
hotel_df = vacay_hotel
# Out:
#     City Name      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 60      kutum  14.2000   24.6667    295.63      15.0        11.0        2.50
# 114    bethel  41.3712  -73.4140    289.15      29.0         1.0        2.06
# 140   sakakah  29.9697   40.2064    291.15      25.0         0.0        1.54
# 242    shache  38.4167   77.2406    287.76      20.0         0.0        0.31
# 419  gallatin  45.6666 -111.2008    288.71      26.0         1.0        1.54
# 467      esna  25.2934   32.5540    295.15      24.0         0.0        1.03
# 501       hit  33.6416   42.8251    296.33      29.0         0.0        2.44
# 512   ushtobe  45.2514   77.9838    287.44      32.0         3.0        1.92
# 536      guna  24.6500   77.3167    299.62      18.0         0.0        2.45
# 547   yangcun  39.3639  117.0603    291.15      20.0         0.0        4.00
# 555   ratholo -22.7245   27.5720    291.04      22.0         0.0        0.49
# ...

# %%
hotel_df['Hotel Names'] = ""
# Out:
# C:\Users\Public\Downloads\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hotel_df
# Out:
#     City Name      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 60      kutum  14.2000   24.6667    295.63      15.0        11.0        2.50
# 114    bethel  41.3712  -73.4140    289.15      29.0         1.0        2.06
# 140   sakakah  29.9697   40.2064    291.15      25.0         0.0        1.54
# 242    shache  38.4167   77.2406    287.76      20.0         0.0        0.31
# 419  gallatin  45.6666 -111.2008    288.71      26.0         1.0        1.54
# 467      esna  25.2934   32.5540    295.15      24.0         0.0        1.03
# 501       hit  33.6416   42.8251    296.33      29.0         0.0        2.44
# 512   ushtobe  45.2514   77.9838    287.44      32.0         3.0        1.92
# 536      guna  24.6500   77.3167    299.62      18.0         0.0        2.45
# 547   yangcun  39.3639  117.0603    291.15      20.0         0.0        4.00
# 555   ratholo -22.7245   27.5720    291.04      22.0         0.0        0.49
# ...

# %%
#type : lodging

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
parmas = { 'key' : gkey, 
         'input' : 'lodging'}
coords = [['Lat', 'Lng']]
location ='radius@' + (coords)
params{'locationbias' : location }

hotel_df.loc[index, 'Hotel Names'] = hotelname['candidates'][0]['name']
# Out:
#   File "<ipython-input-138-f0e733810810>", line 6
#     params{'locationbias' : location }
#           ^
# SyntaxError: invalid syntax

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?'
params = { 'key' : gkey, 
         'input' : 'lodging',
         'inputtype' : 'textquery',
         'fields': 'name'}

for index,rows in hotel_df.iterrows() : 
    lat = rows['Lat']
    lng = rows['Lng']
    location =f"circle:5000@{lat},{lng}"
    params['locationbias'] = location 
    
    hotelname = requests.get(base_url, params=params).json()
    ##try : 
    hotel_df.loc[index, 'Hotel Names'] = hotelname['candidates'][0]['name']
    
    #except : 
        #print('woops')
# Out:
# C:\Users\Public\Downloads\Anaconda\envs\PythonData\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
hotel_df
# Out:
#     City Name      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 60      kutum  14.2000   24.6667    295.63      15.0        11.0        2.50
# 114    bethel  41.3712  -73.4140    289.15      29.0         1.0        2.06
# 140   sakakah  29.9697   40.2064    291.15      25.0         0.0        1.54
# 242    shache  38.4167   77.2406    287.76      20.0         0.0        0.31
# 419  gallatin  45.6666 -111.2008    288.71      26.0         1.0        1.54
# 467      esna  25.2934   32.5540    295.15      24.0         0.0        1.03
# 501       hit  33.6416   42.8251    296.33      29.0         0.0        2.44
# 512   ushtobe  45.2514   77.9838    287.44      32.0         3.0        1.92
# 536      guna  24.6500   77.3167    299.62      18.0         0.0        2.45
# 547   yangcun  39.3639  117.0603    291.15      20.0         0.0        4.00
# 555   ratholo -22.7245   27.5720    291.04      22.0         0.0        0.49
# ...

# %%
for index,rows in hotel_df.iterrows() :
    a = rows['Lat']
    b=rows['Lng']
    print(a)
# Out:
# 14.2
# 41.3712
# 29.9697
# 38.4167
# 45.6666
# 25.2934
# 33.6416
# 45.2514
# 24.65
# 39.3639
# -22.7245
# 20.7072

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
params = { 'key' : gkey, 
         'input' : 'lodging',
         'inputtype' : 'textquery',
          'fields' : 'name',
         'locationbias' : "circle:5000@14.2000,24.6667"}

# %%
a=requests.get(base_url, params=params).json()
a['candidates'][0]['name']
# Out:
# 'Budget Motel'

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Names}</dd>
<dt>City</dt><dd>{City Name}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
markers=gmaps.marker_layer(locations, hotel_info)

# %%
humidity.add_layer(markers)

# %%
humidity
# Out:
# Figure(layout=FigureLayout(height='420px'))
